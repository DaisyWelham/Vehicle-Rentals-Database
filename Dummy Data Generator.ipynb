# %% [markdown]
# This code is designed to generate dummy data for a MySQL database. We need first names, surnames, and email adresses.

# %%
import random as r

# %%
firstNames = [
    # A
    "Aaron", "Abigail", "Adam", "Adrian", "Aidan", "Aisha", "Alana", "Albert", "Alejandro", "Alex",
    "Alexa", "Alexander", "Alexandra", "Alexis", "Alice", "Alicia", "Alisha", "Alison", "Allison", "Alyssa",
    "Amara", "Amanda", "Amber", "Amelia", "Amy", "Ana", "Anastasia", "Andrea", "Andres", "Andrew",
    "Angela", "Angelica", "Anita", "Ann", "Anna", "Anne", "Annie", "Anthony", "Antonio", "April",
    "Aria", "Ariana", "Arianna", "Ariel", "Arthur", "Ashley", "Ashton", "Aubrey", "Audrey", "Austin",
    
    # B
    "Barbara", "Beatrice", "Becky", "Belinda", "Ben", "Benjamin", "Bernard", "Beth", "Bethany", "Betty",
    "Beverly", "Bianca", "Bill", "Billy", "Blake", "Bob", "Bobby", "Bonnie", "Brad", "Bradley",
    "Brandon", "Brandy", "Brenda", "Brent", "Brett", "Brian", "Brianna", "Bridget", "Brittany", "Brooke",
    "Bruce", "Bryan", "Byron",

    # C
    "Caleb", "Cameron", "Camila", "Candace", "Carl", "Carla", "Carlos", "Carmen", "Carol", "Carole",
    "Carolina", "Caroline", "Carolyn", "Carrie", "Casey", "Cassandra", "Catherine", "Cathy", "Cecilia", "Cedric",
    "Chad", "Charlene", "Charles", "Charlie", "Charlotte", "Chase", "Chelsea", "Chloe", "Chris", "Christian",
    "Christina", "Christine", "Christopher", "Claire", "Clara", "Claudia", "Clayton", "Clifford", "Clint", "Clinton",
    "Cody", "Colin", "Colleen", "Connie", "Connor", "Constance", "Corey", "Courtney", "Craig", "Crystal",

    # D
    "Daisy", "Dakota", "Dale", "Dallas", "Damian", "Damon", "Dan", "Dana", "Daniel", "Daniela",
    "Danielle", "Danny", "Daphne", "Darlene", "Darnell", "Darren", "Dave", "David", "Dawn", "Dean",
    "Deborah", "Debra", "Delia", "Denise", "Dennis", "Derek", "Desiree", "Destiny", "Diana", "Diane",
    "Dominic", "Don", "Donald", "Donna", "Doris", "Dorothy", "Doug", "Douglas", "Drew", "Duane",
    "Dustin", "Dwayne", "Dwight", "Dylan",

    # E
    "Earl", "Ed", "Eddie", "Edgar", "Edith", "Edmund", "Eduardo", "Edward", "Edwin", "Eileen",
    "Elaine", "Eleanor", "Elena", "Eli", "Elijah", "Elisa", "Elise", "Elizabeth", "Ella", "Ellen",
    "Elliot", "Eloise", "Elsa", "Elton", "Elvira", "Elyse", "Emerson", "Emilia", "Emily", "Emma",
    "Emmanuel", "Enrique", "Eric", "Erica", "Erik", "Erin", "Ernest", "Esmeralda", "Esteban", "Esther",
    "Ethan", "Ethel", "Eugene", "Eva", "Evan", "Evelyn",

    # F
    "Faith", "Felicia", "Felix", "Fernando", "Fiona", "Florence", "Frances", "Francesca", "Francis", "Francisco",
    "Frank", "Franklin", "Fred", "Freddie", "Frederick",

    # G
    "Gabriel", "Gabriela", "Gabriella", "Gail", "Gareth", "Garrett", "Gary", "Gavin", "Gene", "Geoffrey",
    "George", "Georgia", "Gerald", "Gertrude", "Gina", "Ginger", "Gladys", "Glenda", "Gloria", "Grace",
    "Grant", "Greg", "Gregory", "Guillermo", "Guy",

    # H
    "Hailey", "Hannah", "Harley", "Harold", "Harrison", "Harry", "Harvey", "Hazel", "Heather", "Heidi",
    "Helen", "Helena", "Henry", "Herbert", "Holly", "Hope", "Howard", "Hudson", "Hugh", "Hunter",

    # I
    "Ian", "Ibrahim", "Ida", "Ignacio", "Imogen", "India", "Ines", "Ingrid", "Irene", "Iris",
    "Irma", "Isaac", "Isabel", "Isabella", "Isabelle", "Isaiah", "Isidro", "Isla", "Israel", "Ivan",

    # J
    "Jack", "Jackie", "Jackson", "Jacob", "Jacqueline", "Jade", "Jaime", "Jake", "Jalen", "James",
    "Jamie", "Jan", "Jane", "Janet", "Janice", "Jared", "Jasmine", "Jason", "Javier", "Jay",
    "Jayden", "Jean", "Jeanette", "Jeff", "Jeffery", "Jeffrey", "Jenna", "Jennifer", "Jenny", "Jeremiah",
    "Jeremy", "Jerome", "Jerry", "Jesse", "Jessica", "Jill", "Joan", "Joanna", "Joanne", "Jodie",
    "Joe", "Joel", "Joey", "John", "Johnny", "Jon", "Jonathan", "Jordan", "Jorge", "Jose",
    "Joseph", "Josephine", "Josh", "Joshua", "Josie", "Joy", "Joyce", "Juan", "Judith", "Judy",
    "Julia", "Julian", "Julie", "Juliet", "June", "Justin",

    # K
    "Kaitlyn", "Kara", "Karen", "Karina", "Karl", "Katherine", "Kathleen", "Kathryn", "Kathy", "Katie",
    "Kay", "Kayla", "Kaylee", "Keith", "Kelly", "Kelsey", "Kelvin", "Ken", "Kendra", "Kenneth",
    "Kenny", "Kent", "Kevin", "Kim", "Kimberly", "Kirk", "Kristen", "Kristin", "Kyle", "Kylie",

    # L
    "Lacey", "Lance", "Larry", "Laura", "Lauren", "Laurie", "Lawrence", "Leah", "Lee", "Leo",
    "Leon", "Leonard", "Leonardo", "Leslie", "Lester", "Liam", "Lillian", "Lily", "Linda", "Lindsay",
    "Lisa", "Logan", "Lois", "Lola", "Loretta", "Lori", "Lorraine", "Louis", "Louise", "Lucas",
    "Lucia", "Lucy", "Luis", "Luke", "Lydia",

    # M
    "Mabel", "Mackenzie", "Madeline", "Madison", "Maggie", "Malcolm", "Manuel", "Marc", "Marcia", "Marco",
    "Marcus", "Margaret", "Maria", "Mariah", "Marian", "Marie", "Marilyn", "Marina", "Mario", "Marion",
    "Marissa", "Mark", "Marlene", "Martha", "Martin", "Marvin", "Mary", "Mason", "Mathew", "Matthew",
    "Maureen", "Maurice", "Max", "Maxine", "Megan", "Melanie", "Melinda", "Melissa", "Melody", "Mercedes",
    "Meredith", "Mia", "Michael", "Micheal", "Michelle", "Miguel", "Mildred", "Milton", "Miriam", "Molly",
    "Monica", "Morgan",

    # N
    "Nancy", "Naomi", "Natalia", "Natalie", "Natasha", "Nathan", "Nathaniel", "Neal", "Ned", "Neil",
    "Nelson", "Nicholas", "Nicole", "Nina", "Noah", "Noel", "Nora", "Norma", "Norman", "Nyla",

    # O
    "Olga", "Oliver", "Olivia", "Omar", "Opal", "Ophelia", "Orlando", "Oscar", "Owen",

    # P
    "Pam", "Pamela", "Pat", "Patricia", "Patrick", "Paul", "Paula", "Pauline", "Pearl", "Pedro",
    "Peggy", "Penelope", "Perry", "Pete", "Peter", "Philip", "Phillip", "Phoebe", "Phyllis", "Preston",

    # Q
    "Quentin", "Quincy", "Quinn", "Quinton",

    # R
    "Rachael", "Rachel", "Rafael", "Ralph", "Ramona", "Randall", "Randy", "Raquel", "Ray", "Raymond",
    "Rebecca", "Rebekah", "Regina", "Reginald", "Rene", "Renee", "Rhonda", "Ricardo", "Richard", "Rick",
    "Ricky", "Rita", "Rob", "Robbie", "Robert", "Roberta", "Robin", "Rochelle", "Rodney", "Roger",
    "Roland", "Ron", "Ronald", "Rosa", "Rose", "Rosemary", "Ross", "Roy", "Ruben", "Ruby",
    "Russell", "Ruth", "Ryan",

    # S
    "Sabrina", "Sadie", "Sally", "Salvador", "Sam", "Samantha", "Samuel", "Sandra", "Sandy", "Sara",
    "Sarah", "Saul", "Savannah", "Scott", "Sean", "Sebastian", "Sergio", "Seth", "Shane", "Shannon",
    "Sharon", "Shaun", "Shawn", "Sheila", "Shelby", "Sheldon", "Shelley", "Sherri", "Sherry", "Sheryl",
    "Shirley", "Sidney", "Sierra", "Simon", "Sofia", "Sonia", "Sonya", "Sophia", "Sophie", "Spencer",
    "Stacey", "Stacy", "Stan", "Stanley", "Stella", "Stephanie", "Stephen", "Steve", "Steven", "Stewart",
    "Sue", "Summer", "Susan", "Suzanne", "Sydney", "Sylvia",

    # T
    "Tabitha", "Tamara", "Tami", "Tammy", "Tanya", "Tara", "Taylor", "Ted", "Teresa", "Terrance",
    "Terrell", "Terri", "Terry", "Theodore", "Theresa", "Thomas", "Tiffany", "Tim", "Timothy", "Tina",
    "Toby", "Todd", "Tom", "Tommy", "Toni", "Tony", "Tonya", "Tracy", "Travis", "Trent",
    "Trevor", "Troy", "Trudy", "Tyler", "Tyrone",

    # U
    "Ulysses", "Uma", "Umar", "Uriah", "Uriel",

    # V
    "Valerie", "Vanessa", "Vera", "Verna", "Veronica", "Vicki", "Vickie", "Victor", "Victoria", "Vince",
    "Vincent", "Viola", "Violet", "Virginia", "Vivian",

    # W
    "Wade", "Wallace", "Walter", "Wanda", "Warren", "Wayne", "Wesley", "Whitney", "Wilbur", "Will",
    "William", "Willie", "Wilson", "Winston", "Wyatt",

    # X
    "Xander", "Xavier", "Ximena", "Xochitl",

    # Y
    "Yasmin", "Yolanda", "Yvette", "Yvonne", "Yuri",

    # Z
    "Zachary", "Zane", "Zara", "Zelda", "Zoe", "Zoey"
]

surnames = [
    # A
    "Abbott", "Abraham", "Acevedo", "Acosta", "Adams", "Adkins", "Aguilar", "Aguirre", "Alexander", "Alford",
    "Allen", "Allison", "Alston", "Alvarado", "Alvarez", "Andersen", "Anderson", "Andrade", "Andrews", "Anthony",
    "Archer", "Arellano", "Armstrong", "Arnold", "Arroyo", "Ashley", "Atkins", "Atkinson", "Austin", "Avila",

    # B
    "Bailey", "Baird", "Baker", "Baldwin", "Ball", "Ballard", "Banks", "Barber", "Barker", "Barnes",
    "Barnett", "Barrett", "Barron", "Barry", "Bartlett", "Barton", "Bass", "Bates", "Battle", "Bauer",
    "Baxter", "Beach", "Beard", "Beasley", "Beck", "Becker", "Bell", "Bender", "Benjamin", "Bennett",
    "Benson", "Bentley", "Berg", "Berger", "Bernard", "Berry", "Best", "Bird", "Bishop", "Black",
    "Blackburn", "Blackwell", "Blair", "Blake", "Blanchard", "Blankenship", "Blevins", "Bolton", "Bond", "Bonner",
    "Booker", "Boone", "Booth", "Bowen", "Bowers", "Bowman", "Boyd", "Boyer", "Boyle", "Bradford",
    "Bradley", "Bradshaw", "Brady", "Branch", "Bray", "Brennan", "Brewer", "Bridges", "Briggs", "Bright",
    "Britt", "Brock", "Brooks", "Brown", "Browning", "Bruce", "Bryan", "Bryant", "Buchanan", "Buck",
    "Buckley", "Bullock", "Burch", "Burgess", "Burke", "Burnett", "Burns", "Burris", "Burt", "Burton",
    "Bush", "Butler", "Byers", "Byrd",

    # C
    "Caldwell", "Calhoun", "Callahan", "Camacho", "Cameron", "Campbell", "Campos", "Cannon", "Cantrell", "Cantu",
    "Cardenas", "Carey", "Carlson", "Carney", "Carpenter", "Carr", "Carrillo", "Carroll", "Carson", "Carter",
    "Case", "Casey", "Castaneda", "Castillo", "Castro", "Cervantes", "Chambers", "Chan", "Chandler", "Chang",
    "Chapman", "Charles", "Chavez", "Chen", "Cherry", "Christensen", "Christian", "Church", "Clark", "Clarke",
    "Clay", "Clayton", "Clements", "Clemons", "Cleveland", "Cline", "Cobb", "Cochran", "Coffey", "Cohen",
    "Cole", "Coleman", "Collier", "Collins", "Colon", "Compton", "Conley", "Conner", "Conrad", "Contreras",
    "Conway", "Cook", "Cooke", "Cooley", "Cooper", "Copeland", "Cortez", "Costa", "Cox", "Craig",
    "Crane", "Crawford", "Crosby", "Cross", "Cruz", "Cummings", "Cunningham", "Curry", "Curtis",

    # D
    "Dalton", "Daniel", "Daniels", "Daugherty", "Davenport", "David", "Davidson", "Davis", "Dawson", "Day",
    "Decker", "Dejesus", "Delacruz", "Delaney", "Deleon", "Delgado", "Dennis", "Diaz", "Dickerson", "Dickson",
    "Dillard", "Dillon", "Dixon", "Dodson", "Dominguez", "Donaldson", "Donovan", "Dorsey", "Dotson", "Douglas",
    "Downs", "Doyle", "Drake", "Dudley", "Duffy", "Duke", "Duncan", "Dunlap", "Dunn", "Durham",
    "Dyer",

    # E
    "Eaton", "Edwards", "Elliott", "Ellis", "Ellison", "Emerson", "England", "English", "Erickson", "Espinoza",
    "Esquivel", "Estes", "Estrada", "Evans",

    # F
    "Farley", "Farmer", "Farrell", "Faulkner", "Ferguson", "Fernandez", "Ferrell", "Fields", "Figueroa", "Finch",
    "Finley", "Fischer", "Fisher", "Fitzgerald", "Fleming", "Fletcher", "Flores", "Flowers", "Floyd", "Flynn",
    "Foley", "Forbes", "Ford", "Foreman", "Foster", "Fowler", "Fox", "Francis", "Franco", "Frank",
    "Franklin", "Frederick", "Freeman", "French", "Frost", "Fry", "Frye", "Fuentes", "Fuller",

    # G
    "Gaines", "Gallagher", "Gallegos", "Galloway", "Gamble", "Garcia", "Gardner", "Garner", "Garrett", "Garrison",
    "Garza", "Gates", "Gay", "Gentry", "George", "Gibbs", "Gibson", "Gilbert", "Giles", "Gill",
    "Gillespie", "Gilliam", "Gilmore", "Glass", "Glenn", "Glover", "Golden", "Gomez", "Gonzales", "Gonzalez",
    "Good", "Goodman", "Goodwin", "Gordon", "Gould", "Graham", "Grant", "Graves", "Gray", "Green",
    "Greene", "Greer", "Gregory", "Griffin", "Griffith", "Grimes", "Gross", "Guerra", "Guerrero", "Guthrie",
    "Gutierrez", "Guy", "Guzman",

    # H
    "Hahn", "Hale", "Haley", "Hall", "Hamilton", "Hammond", "Hampton", "Hancock", "Haney", "Hanna",
    "Hansen", "Hanson", "Hardin", "Harding", "Hardy", "Harmon", "Harper", "Harrell", "Harrington", "Harris",
    "Harrison", "Hart", "Hartman", "Harvey", "Hatfield", "Hawkins", "Hayden", "Hayes", "Haynes", "Hays",
    "Head", "Heath", "Hebert", "Henderson", "Hendricks", "Hendrix", "Henry", "Hensley", "Henson", "Herman",
    "Hernandez", "Herrera", "Herring", "Hess", "Hester", "Hewitt", "Hickman", "Hicks", "Higgins", "Hill",
    "Hines", "Hinton", "Hobbs", "Hodge", "Hodges", "Hoffman", "Hogan", "Holcomb", "Holden", "Holder",
    "Holland", "Holloway", "Holman", "Holmes", "Holt", "Hood", "Hooper", "Hoover", "Hopkins", "Hopper",
    "Horn", "Horne", "Horton", "House", "Houston", "Howard", "Howe", "Howell", "Hubbard", "Huber",
    "Hudson", "Huff", "Huffman", "Hughes", "Hull", "Humphrey", "Hunt", "Hunter", "Hurley", "Hurst",
    "Hutchinson",

    # I
    "Ingram", "Irwin", "Ivey",

    # J
    "Jackson", "Jacobs", "Jacobson", "James", "Jarvis", "Jefferson", "Jenkins", "Jennings", "Jensen", "Jimenez",
    "Johns", "Johnson", "Johnston", "Jones", "Jordan", "Joseph", "Joyce", "Juarez", "Justice",

    # K
    "Kane", "Kaufman", "Keith", "Keller", "Kelley", "Kelly", "Kemp", "Kennedy", "Kent", "Kerr",
    "Key", "Kidd", "Kim", "King", "Kinney", "Kirby", "Kirk", "Klein", "Kline", "Knapp",
    "Knight", "Knowles", "Knox", "Koch", "Kramer", "Krueger",

    # L
    "Lamb", "Lambert", "Lancaster", "Landry", "Lane", "Lang", "Langley", "Lara", "Larsen", "Larson",
    "Lawrence", "Lawson", "Le", "Leach", "Leblanc", "Lee", "Leon", "Leonard", "Lester", "Levine",
    "Levy", "Lewis", "Li", "Lin", "Lindsay", "Lindsey", "Little", "Livingston", "Lloyd", "Logan",
    "Long", "Lopez", "Lott", "Love", "Lowery", "Lucas", "Luna", "Lynch", "Lynn",

    # M
    "Macdonald", "Macias", "Mack", "Madden", "Maddox", "Maldonado", "Malone", "Mann", "Manning", "Marks",
    "Marquez", "Marsh", "Marshall", "Martin", "Martinez", "Mason", "Massey", "Mathews", "Mathis", "Matthews",
    "Maxwell", "May", "Mayer", "Maynard", "Mayo", "Mays", "McBride", "McCall", "McCarthy", "McCarty",
    "McClain", "McClure", "McConnell", "McCormick", "McCoy", "McCray", "McCullough", "McDaniel", "McDonald", "McDowell",
    "McFadden", "McFarland", "McGee", "McGrath", "McGuire", "McIntosh", "McIntyre", "McKay", "McKee", "McKenzie",
    "McKinney", "McKnight", "McLaughlin", "McLean", "McLeod", "McMahon", "McMillan", "McNeil", "McPherson", "Meadows",
    "Medina", "Mejia", "Melendez", "Melton", "Mendez", "Mendoza", "Mercado", "Mercer", "Merrill", "Merritt",
    "Meyer", "Meyers", "Michael", "Middleton", "Miles", "Miller", "Mills", "Miranda", "Mitchell", "Molina",
    "Monroe", "Montgomery", "Montoya", "Moody", "Moon", "Mooney", "Moore", "Morales", "Moran", "Moreno",
    "Morgan", "Morin", "Morris", "Morrison", "Morrow", "Morse", "Morton", "Moses", "Mosley", "Moss",
    "Mueller", "Mullen", "Mullins", "Munoz", "Murphy", "Murray", "Myers",

    # N
    "Nash", "Navarro", "Neal", "Nelson", "Newman", "Newton", "Nguyen", "Nichols", "Nicholson", "Nielsen",
    "Nieves", "Nixon", "Noble", "Noel", "Nolan", "Norman", "Norris", "Norton", "Novak",

    # O
    "Ochoa", "Oconnor", "Odom", "Oliver", "Olsen", "Olson", "Oneal", "Oneil", "Orr",
    "Ortega", "Ortiz", "Osborn", "Osborne", "Owen", "Owens",

    # P
    "Pace", "Padilla", "Page", "Palmer", "Park", "Parker", "Parks", "Parrish", "Parsons", "Pate",
    "Patel", "Patrick", "Patterson", "Patton", "Paul", "Payne", "Pearson", "Peck", "Pena", "Pennington",
    "Perez", "Perkins", "Perry", "Peters", "Petersen", "Peterson", "Petty", "Pham", "Phillips", "Pierce",
    "Pittman", "Pitts", "Pollard", "Poole", "Pope", "Porter", "Potter", "Potts", "Powell", "Powers",
    "Pratt", "Preston", "Price", "Prince", "Pruitt",

    # Q
    "Quinn", "Quintero",

    # R
    "Ramirez", "Ramos", "Ramsey", "Randall", "Randolph", "Rasmussen", "Ray", "Raymond", "Reed", "Reese",
    "Reeves", "Reid", "Reilly", "Reyes", "Reynolds", "Rhodes", "Rice", "Rich", "Richard", "Richards",
    "Richardson", "Richmond", "Riddle", "Riggs", "Riley", "Rios", "Rivas", "Rivera", "Rivers", "Roach",
    "Robbins", "Roberson", "Roberts", "Robertson", "Robinson", "Robles", "Rocha", "Rodgers", "Rodriguez", "Rodriquez",
    "Rogers", "Rojas", "Rollins", "Roman", "Romero", "Rosa", "Rosales", "Rosario", "Rose", "Ross",
    "Roth", "Rowe", "Rowland", "Roy", "Ruiz", "Rush", "Russell", "Rutledge", "Ryan",

    # S
    "Salas", "Salazar", "Salinas", "Sampson", "Sampson", "Sanchez", "Sanders", "Sandoval", "Sanford", "Santana",
    "Santiago", "Santos", "Sargent", "Saunders", "Savage", "Sawyer", "Schmidt", "Schneider", "Schroeder", "Schultz",
    "Schwartz", "Scott", "Sears", "Sellers", "Serrano", "Sexton", "Shaffer", "Shannon", "Sharp", "Sharpe",
    "Shaw", "Shelton", "Shepard", "Shepherd", "Sheppard", "Sherman", "Shields", "Short", "Silva", "Simmons",
    "Simon", "Simpson", "Sims", "Singleton", "Skinner", "Slater", "Sloan", "Small", "Smith", "Snider",
    "Snow", "Snyder", "Solis", "Solomon", "Sosa", "Soto", "Sparks", "Spears", "Spence", "Spencer",
    "Stafford", "Stanley", "Stanton", "Stark", "Steele", "Stein", "Stephens", "Stephenson", "Stevens", "Stevenson",
    "Stewart", "Stokes", "Stone", "Stout", "Strickland", "Strong", "Stuart", "Suarez", "Sullivan", "Summers",
    "Sutton", "Swanson", "Sweeney",

    # T
    "Talley", "Tanner", "Tate", "Taylor", "Terrell", "Terry", "Thomas", "Thompson", "Thornton", "Tillman",
    "Todd", "Torres", "Townsend", "Tran", "Travis", "Trevino", "Trujillo", "Tucker", "Turner", "Tyler",

    # U
    "Underwood", "Valdez", "Valencia", "Valentine", "Valenzuela", "Vance", "Vang", "Vargas", "Vasquez", "Vaughan",
    "Vaughn", "Vega", "Velasquez", "Velazquez", "Velez", "Villarreal", "Vincent", "Vinson",

    # W
    "Wade", "Wagner", "Walker", "Wall", "Wallace", "Waller", "Walls", "Walsh", "Walter", "Walters",
    "Walton", "Ward", "Ware", "Warner", "Warren", "Washington", "Waters", "Watkins", "Watson", "Watts",
    "Weaver", "Webb", "Weber", "Webster", "Weeks", "Weiss", "Welch", "Wells", "West", "Wheeler",
    "Whitaker", "White", "Whitehead", "Whitfield", "Whitley", "Whitney", "Wiggins", "Wilcox", "Wilder", "Wiley",
    "Wilkerson", "Wilkins", "Wilkinson", "William", "Williams", "Williamson", "Willis", "Wilson", "Winters", "Wise",
    "Witt", "Wolf", "Wolfe", "Wong", "Wood", "Woodard", "Woods", "Woodward", "Wooten", "Workman",
    "Wright", "Wyatt", "Wynn",

    # Y
    "Yates", "York", "Young",

    # Z
    "Zamora", "Zavala", "Zhang"
]

# %%
def generateAll():
    f = r.choice(firstNames)
    s = r.choice(surnames)
    name = "".join([f, " ", s])
    
    emailHead = r.choice([f.lower(), f[0].lower(), "".join([f[0].lower(), "."]), "".join([f[0].lower(), "_"])])
    emailTail = r.choice([s.lower()])
    emailDomain = r.choice(["gmail", "hotmail", "aol", "outlook", "btinternet", "yahoo", "protonmail"])
    email = "".join([emailHead, emailTail, "@", emailDomain, ".com"])
    
    year = str(r.randint(2010, 2025))
    month = str(r.randint(1, 12))
    date = str(r.randint(1, 28))
    fulldate = "".join([year,"-",month,"-",date])
    print("".join(["('",name,"','",email,"','",fulldate,"'),"]))

for i in range(100):
    generateAll()
# Out:
# ('Constance Hensley','c_hensley@outlook.com','2018-6-11'),
# ('Randy Ryan','randyryan@gmail.com','2020-9-22'),
# ('Colleen Allison','c_allison@gmail.com','2018-8-13'),
# ('Kimberly Martinez','k.martinez@btinternet.com','2019-12-16'),
# ('Beth Holt','bethholt@gmail.com','2025-4-8'),
# ('Umar Elliott','u.elliott@aol.com','2010-4-6'),
# ('Tracy Finley','tracyfinley@yahoo.com','2019-5-11'),
# ('Ted Wilkerson','twilkerson@btinternet.com','2021-11-24'),
# ('George Fitzgerald','gfitzgerald@yahoo.com','2018-12-6'),
# ('Amanda Kelly','a_kelly@yahoo.com','2024-9-6'),
# ('Jodie Jensen','jjensen@btinternet.com','2012-1-18'),
# ('Elliot Beasley','e.beasley@gmail.com','2018-10-23'),
# ('Tina Walls','twalls@outlook.com','2010-9-27'),
# ('Ashton Garrison','a.garrison@btinternet.com','2025-11-25'),
# ('Garrett Bennett','garrettbennett@aol.com','2012-11-6'),
# ('Eileen Parker','e_parker@protonmail.com','2010-9-18'),
# ('Lois Barker','l.barker@hotmail.com','2024-6-16'),
# ...
